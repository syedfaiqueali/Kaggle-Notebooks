# %% [markdown]
# <a href="https://www.kaggle.com/code/faiqueali/london-temperature-assessing-normality?scriptVersionId=158401038" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Imports

# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, probplot

warnings.simplefilter('ignore')

sns.set_theme(style="whitegrid")

# %% [markdown]
# # Constant

# %%
DATASET_PATH = '/kaggle/input/london-weather-data/london_weather.csv'

# %% [markdown]
# # Code

# %%
df = pd.read_csv(DATASET_PATH)
df.head(5)
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %% [markdown]
# ## Mean Temperature - Distribution Analysis

# %%
# Plot histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['mean_temp'], bins=20, kde=True, color='green', edgecolor='black')
plt.title('Histogram of Mean Temperature')
plt.xlabel('Mean Temperature')
plt.ylabel('Frequency')

# Plot probability plot (quantile-quantile plot)
plt.subplot(1, 2, 2)
probplot(df['mean_temp'], dist='norm', plot=plt)
plt.title('Probability Plot (Q-Q Plot)')

# Show the plots
plt.tight_layout()
plt.show()

# Perform Shapiro-Wilk test
stat, p_value = shapiro(df['mean_temp'])

# Set the significance level (e.g., 0.05)
alpha = 0.05

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("Mean temperature is normally distributed (fail to reject H0)")
else:
    print("Mean temperature is not normally distributed (reject H0)")
# Out:
# Mean temperature is normally distributed (fail to reject H0)

# %% [markdown]
# # Global Radiation - Distribution Analysis

# %%
# Plot histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['global_radiation'], bins=20, kde=True, color='green', edgecolor='black')
plt.title('Histogram of Global Radiation')
plt.xlabel('Global Radiation')
plt.ylabel('Frequency')

# Plot probability plot (quantile-quantile plot)
plt.subplot(1, 2, 2)
probplot(df['global_radiation'], dist='norm', plot=plt,)
plt.title('Probability Plot (Q-Q Plot)')

# Show the plots
plt.tight_layout()
plt.show()

# Perform Shapiro-Wilk test
stat, p_value = shapiro(df['global_radiation'])

# Set the significance level (e.g., 0.05)
alpha = 0.05

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("Global Radiation is normally distributed (fail to reject H0)")
else:
    print("Global Radiation is not normally distributed (reject H0)")
# Out:
# Global Radiation is normally distributed (fail to reject H0)

# %% [markdown]
# # Precipation - Distribution Analysis

# %%
# Plot histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['precipitation'], bins=20, kde=True, color='green', edgecolor='black')
plt.title('Histogram of Precipitation')
plt.xlabel('Precipitation')
plt.ylabel('Frequency')

# Plot probability plot (quantile-quantile plot)
plt.subplot(1, 2, 2)
probplot(df['precipitation'], dist='norm', plot=plt,)
plt.title('Probability Plot (Q-Q Plot)')

# Show the plots
plt.tight_layout()
plt.show()

# Perform Shapiro-Wilk test
stat, p_value = shapiro(df['precipitation'])

# Set the significance level (e.g., 0.05)
alpha = 0.05

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("Precipitation is normally distributed (fail to reject H0)")
else:
    print("Precipitation is not normally distributed (reject H0)")
# Out:
# Precipitation is normally distributed (fail to reject H0)

# %% [markdown]
# # Sunshine - Distribution Analysis

# %%
# Plot histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['sunshine'], bins=20, kde=True, color='green', edgecolor='black')
plt.title('Histogram of Sunshine')
plt.xlabel('Sunshine')
plt.ylabel('Frequency')

# Plot probability plot (quantile-quantile plot)
plt.subplot(1, 2, 2)
probplot(df['sunshine'], dist='norm', plot=plt,)
plt.title('Probability Plot (Q-Q Plot)')

# Show the plots
plt.tight_layout()
plt.show()

# Perform Shapiro-Wilk test
stat, p_value = shapiro(df['sunshine'])

# Set the significance level (e.g., 0.05)
alpha = 0.05

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("Sunshine is normally distributed (fail to reject H0)")
else:
    print("Sunshine is not normally distributed (reject H0)")
# Out:
# Sunshine is not normally distributed (reject H0)
