# %% [markdown]
# # Imports

# %%
import re
import requests
import time
import random
import numpy as np
import pandas as pd

from urllib.parse import quote

# %% [markdown]
# # Constant

# %%
DATASET_PATH = '/kaggle/input/zocdoc/df_combined.csv'

# %% [markdown]
# # Utils

# %%
def extract_address_components(address):
    components = address.split(',')
    
    if len(components) >= 3:
        street_number_and_name = components[0].strip() + ', ' + components[1].strip()
        city = components[2].strip()
        return f"{street_number_and_name}, {city}"
    else:
        return "N/A"


def fetch_facility_name(street, state, postal_code):
    street_encoded = quote(street)
    url = f"https://nominatim.openstreetmap.org/search.php?street={street_encoded}&state={state}&postalcode={postal_code}&format=jsonv2&limit=1"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        if len(data) > 0:
            name = data[0].get('name')
            address = extract_address_components(data[0].get('display_name'))
            return (name.lower(), address.lower())
            print(f"Name: {name}, Add: {address}")
    return ("N/A", "N/A")

# %% [markdown]
# # Code

# %%
df = pd. read_csv(DATASET_PATH)
df.head(5)
# Out:
#                      name     job_title  rating  \
# 0     dr. david bolon, md  cardiologist    4.93
# 1      dr. anil gupta, md  cardiologist    5.00
# 2   dr. fadi a elatat, md  cardiologist    4.69
# 3  dr. stephen sherer, md  cardiologist    4.90
# 4   dr. fadi a elatat, md  cardiologist    4.69
#
#                                       street_address address_locality region  \
# 0                            133 e 58th st, ste 1402         new york     NY
# 1  1314 hooper ave - ste 2b - 1314 hooper ave, st...       toms river     NJ
# 2  facv consultants pc-montclair - 127 pine st, s...        montclair     NJ
# 3                                    714 bergen blvd       ridgefield     NJ
# 4  facv consultants pc-union - 1945 morris ave, s...            union     NJ
#
#    postal_code  is_dr  is_nurse  is_assistant
# 0        10022      1         0             0
# 1         8753      1         0             0
# 2         7042      1         0             0
# 3         7657      1         0             0
# 4         7083      1         0             0

# %%
df = df.assign(facility_name='', facility_address='')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249 entries, 0 to 2248
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2249 non-null   object
#  1   job_title         2249 non-null   object
#  2   rating            2164 non-null   float64
#  3   street_address    2025 non-null   object
#  4   address_locality  2025 non-null   object
#  5   region            2249 non-null   object
#  6   postal_code       2249 non-null   int64
#  7   is_dr             2249 non-null   int64
#  8   is_nurse          2249 non-null   int64
#  9   is_assistant      2249 non-null   int64
#  10  facility_name     2249 non-null   object
#  11  facility_address  2249 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 211.0+ KB

# %%
df.head(2)
# Out:
#                   name     job_title  rating  \
# 0  dr. david bolon, md  cardiologist    4.93
# 1   dr. anil gupta, md  cardiologist    5.00
#
#                                       street_address address_locality region  \
# 0                            133 e 58th st, ste 1402         new york     NY
# 1  1314 hooper ave - ste 2b - 1314 hooper ave, st...       toms river     NJ
#
#    postal_code  is_dr  is_nurse  is_assistant facility_name facility_address
# 0        10022      1         0             0
# 1         8753      1         0             0

# %%
# %%time
# for row in df[:100].itertuples(index=True):
#     if pd.notna(row.street_address):
#         street_address = re.split(',|-', row.street_address)[0]
#         facility_name, facility_add = fetch_facility_name(street=street_address, state=row.region, postal_code=row.postal_code)
#         df.at[row.Index, 'facility_name'] = facility_name
#         df.at[row.Index, 'facility_address'] = facility_add
#         print(row.Index, facility_name, facility_add)
#         time.sleep(random.uniform(1, 3))

# %%
# %%time
# for row in df[99:1000].itertuples(index=True):
#     if pd.notna(row.street_address):
#         street_address = re.split(',|-', row.street_address)[0]
#         facility_name, facility_add = fetch_facility_name(street=street_address, state=row.region, postal_code=row.postal_code)
#         df.at[row.Index, 'facility_name'] = facility_name
#         df.at[row.Index, 'facility_address'] = facility_add
#         print(row.Index, facility_name, facility_add)
#         time.sleep(random.uniform(1, 3))

# %%
# %%time
# for row in df[1000:1200].itertuples(index=True):
#     if pd.notna(row.street_address):
#         street_address = re.split(',|-', row.street_address)[0]
#         facility_name, facility_add = fetch_facility_name(street=street_address, state=row.region, postal_code=row.postal_code)
#         df.at[row.Index, 'facility_name'] = facility_name
#         df.at[row.Index, 'facility_address'] = facility_add
#         print(row.Index, facility_name, facility_add)
#         time.sleep(random.uniform(1, 3))

# %%
# %%time
# for row in df[1200:1500].itertuples(index=True):
#     if pd.notna(row.street_address):
#         street_address = re.split(',|-', row.street_address)[0]
#         facility_name, facility_add = fetch_facility_name(street=street_address, state=row.region, postal_code=row.postal_code)
#         df.at[row.Index, 'facility_name'] = facility_name
#         df.at[row.Index, 'facility_address'] = facility_add
#         print(row.Index, facility_name, facility_add)
#         time.sleep(random.uniform(1, 3))

# %%
# %%time
for row in df[1500:].itertuples(index=True):
    if pd.notna(row.street_address):
        street_address = re.split(',|-', row.street_address)[0]
        facility_name, facility_add = fetch_facility_name(street=street_address, state=row.region, postal_code=row.postal_code)
        df.at[row.Index, 'facility_name'] = facility_name
        df.at[row.Index, 'facility_address'] = facility_add
        print(row.Index, facility_name, facility_add)
        time.sleep(random.uniform(1, 3))
# Out:
# 1500  630, broad street, ridgewood junction
# 1501  630, broad street, ridgewood junction
# 1502 N/A N/A
# 1503 N/A N/A
# 1504 N/A N/A
# 1508 princess road princess road, lawrence township, mercer county
# 1509 cranbury road cranbury road, arrowhead park, arrowhead village
# 1510 spectrum therapeutics of nj spectrum therapeutics of nj, 401, paterson-hamburg turnpike
# 1511  370, grand avenue, davisville
# 1512  300, perrine road, cedarview estates
# 1514 hawks bridge road hawks bridge road, cedar crest manor, carneys point township
# 1515  123, franklin corner road, franklin corner
# 1516  127, pine street, closter
# 1517 N/A N/A
# 1518 union union, morris avenue, union
# 1519  620, cranbury road, gillilandtown
# 1520  1503, east saint georges avenue, roselle
# 1522 hazlet hazlet, holmdel road, mechanicsville
# 1523  8901, john f. kennedy boulevard, hudson heights
# 1524  50, mount prospect avenue, athenia
# 1525 2 journal square plaza 2 journal square plaza, 2, john f. kennedy boulevard
# 1526  784, franklin avenue, nutley
# 1528  8901, john f. kennedy boulevard, hudson heights
# 1529 clifton clifton, elm street, athenia
# 1530 new jersey city university new jersey city university, towers street, west bergen
# 1531 northfield avenue northfield avenue, west orange, essex county
# 1532 N/A N/A
# 1533 clifton clifton, elm street, athenia
# 1534 N/A N/A
# 1535 clifton clifton, elm street, athenia
# 1536 clifton clifton, elm street, athenia
# 1537  443, northfield avenue, saint cloud
# 1538  975, clifton avenue, athenia
# 1539 clifton clifton, elm street, athenia
# 1540 N/A N/A
# 1541 hazlet hazlet, holmdel road, mechanicsville
# 1542  1117, edgebrook drive south, silver ridge park east
# 1543  405, northfield avenue, saint cloud
# 1544  2333, morris avenue, unionburg
# 1545 tices lane tices lane, mid state mall, east brunswick township
# 1546 nj 44 nj 44, verga, west deptford township
# 1547  1203, langhorne-yardley road, highland gate
# 1548  385, south maple avenue, downtown ridgewood
# 1549  290, madison avenue, norwood
# 1550 provident bank provident bank, 161, eagle rock avenue
# 1551  475, prospect avenue, dumont
# 1552  1455, broad street, ridgewood heights
# 1553  140, sylvan avenue, englewood cliffs
# 1555 burger king burger king, 185, 12th street
# 1556  475, prospect avenue, dumont
# 1557 permanent mission of the central african republic to the united nations permanent mission of the central african republic to the united nations, 369, lexington avenue
# 1558  443, northfield avenue, saint cloud
# 1559  638, mount prospect avenue, newark
# 1560  7650, river road, north bergen
# 1561 us highway 46 us highway 46, saddle brook, bergen county
# 1562 spectrum therapeutics of nj spectrum therapeutics of nj, 401, paterson-hamburg turnpike
# 1563  1503, east saint georges avenue, roselle
# 1564  2177, oak tree road, oak tree
# 1565  443, northfield avenue, saint cloud
# 1566 N/A N/A
# 1567  345, south main street, lambertville
# 1568  910, sylvan avenue, englewood cliffs
# 1569  2, lincoln highway, kearny point
# 1570 lefcourt colonial building lefcourt colonial building, 295, madison avenue
# 1571  81, north broadway, hicksville
# 1572  20, cherry tree farm road, new monmouth
# 1573  184, old country road, village of mineola
# 1574 taco bell taco bell, 701, nj 440
# 1575  2175, lemoine avenue, koreatown
# 1576 N/A N/A
# 1577  2124, oak tree road, oak tree
# 1578 permanent mission of the central african republic to the united nations permanent mission of the central african republic to the united nations, 369, lexington avenue
# 1579 the columns the columns, 47, orient way
# 1580 N/A N/A
# 1581  2163, oak tree road, oak tree
# 1582 garden city garden city, park avenue, village of garden city
# 1583  2800, marcus avenue, lake success quadrangle
# 1584  377, jersey avenue, fairview
# 1585  110, west 14th street, manhattan community board 2
# 1586 e14 medical arts e14 medical arts, 332, east 14th street
# 1587 cross street cross street, fairways, lakewood township
# 1588 physical therapists physical therapists, 80, maiden lane
# 1589 i&m liquor i&m liquor, 626, sheepshead bay road
# 1590  2, ohio drive, lake success quadrangle
# 1591 sports injury & pain management clinic of new york sports injury & pain management clinic of new york, 36, west 44th street
# 1594  1, west ridgewood avenue, downtown ridgewood
# 1596  1144, east ridgewood avenue, southeast ridgewood
# 1597  630, broad street, ridgewood junction
# 1598 N/A N/A
# 1599 ridgewood internal medicine ridgewood internal medicine, 190, dayton street
# 1600 N/A N/A
# 1602  290, south livingston avenue, northfield
# 1603 55 55, departures level, newark
# 1604  367, lakehurst road, camelot
# 1605  1104, arnold avenue, clarks landing
# 1606 N/A N/A
# 1607 N/A N/A
# 1608 route 34 route 34, cheesequake, old bridge township
# 1609  158, south main street, lambertville
# 1610 route 34 route 34, cheesequake, old bridge township
# 1611  158, south main street, lambertville
# 1612 N/A N/A
# 1613  175, gunning river road, lincoln park
# 1614 route 34 route 34, cheesequake, old bridge township
# 1615 route 34 route 34, cheesequake, old bridge township
# 1616 attilio's pizza attilio's pizza, 4057, asbury avenue
# 1617 N/A N/A
# 1618 N/A N/A
# 1619  1270, south beverwyck road, parsippany-troy hills
# 1620 N/A N/A
# 1621 N/A N/A
# 1622 N/A N/A
# 1624 route 34 route 34, cheesequake, old bridge township
# 1625  302, high street, northvale
# 1626  3363, john f. kennedy boulevard, union city
# 1627 N/A N/A
# 1628 main street main street, chester township, morris county
# 1629  1622, parker avenue, koreatown
# 1630  133, monroe street, downtown
# 1631 bank of america bank of america, 200, hudson street
# 1632 bank of america bank of america, 200, hudson street
# 1633 ruth road ruth road, brighton at barnegat mobile home park, barnegat township
# 1634 N/A N/A
# 1635  1325, hudson street, uptown
# 1636  253, south washington avenue, bergenfield
# 1637  1325, hudson street, uptown
# 1638 bank of america bank of america, 200, hudson street
# 1639  351, union boulevard, totowa
# 1640  557, south atlantic avenue, aberdeen township
# 1641 north jersey fit club north jersey fit club, 15, corporate drive
# 1642  133, monroe street, downtown
# 1643  1325, hudson street, uptown
# 1644  133, monroe street, downtown
# 1645  13, clyde road, clyde
# 1646  133, monroe street, downtown
# 1647  150, sylvan avenue, englewood cliffs
# 1649 tices lane tices lane, mid state mall, east brunswick township
# 1650  300, kakeout road, kinnelon ridge
# 1651 N/A N/A
# 1653  3553, johnson avenue, spuyten duyvil
# 1654 john t costa agency john t costa agency, 2025, paterson-hamburg turnpike
# 1655 urban table urban table, 665, martinsville road
# 1656 clifton clifton, elm street, athenia
# 1657 tices lane tices lane, mid state mall, east brunswick township
# 1658  1200, green street, iselin
# 1659 N/A N/A
# 1660 richmond physical therapy richmond physical therapy, 3377, richmond avenue
# 1661  33, west 46th street, manhattan community board 5
# 1662 law and mediation office of darren m. shapiro, p.c. law and mediation office of darren m. shapiro, p.c., 99
# 1663  37, east 28th street, manhattan community board 5
# 1664  1100, stewart avenue, east garden city
# 1666  1751, victory boulevard, castleton corners
# 1667  1384, broadway, garment district
# 1668 kidsthrive nyc kidsthrive nyc, 303, 5th avenue
# 1669 otb otb, 3430, sunrise highway
# 1670 port authority bus terminal port authority bus terminal, 625, 8th avenue
# 1671 new rd new rd, highlands, monmouth county
# 1672  2627, hylan boulevard, oakwood
# 1673 enigma.io enigma.io, 245, 5th avenue
# 1674  684, west fingerboard road, arrochar
# 1675  45, emerson plaza east, emerson
# 1676  131, west 35th street, garment district
# 1677  12, east 46th street, manhattan community board 5
# 1678  2014, bergenline avenue, union city
# 1679  544, washington avenue, woodbine
# 1680 N/A N/A
# 1681  630, broad street, ridgewood junction
# 1682 N/A N/A
# 1683 ridgewood internal medicine ridgewood internal medicine, 190, dayton street
# 1684  759, hamburg turnpike, wayne
# 1685  55, kent road, tenafly
# 1686  9, hospital drive, silver ridge
# 1687 N/A N/A
# 1688  509, stillwells corner road, west freehold
# 1689 N/A N/A
# 1690  35, beaverson boulevard, brick township
# 1691 N/A N/A
# 1692  515, iron bridge road, college park
# 1693  55, kent road, tenafly
# 1694 N/A N/A
# 1695 N/A N/A
# 1696  35, beaverson boulevard, brick township
# 1697  505, stillwells corner road, west freehold
# 1698 N/A N/A
# 1699  55, kent road, tenafly
# 1700 north johnson boulevard north johnson boulevard, gloucester city, camden county
# 1701 N/A N/A
# 1702  433, hackensack avenue, hackensack
# 1703  172, summerhill road, east brunswick township
# 1704  195, gettysburg way, lincoln park
# 1705 bell works bell works, 101, crawfords corner road
# 1706 N/A N/A
# 1707 N/A N/A
# 1708 south avenue south avenue, norwood, bergen county
# 1709 bell works bell works, 101, crawfords corner road
# 1710 N/A N/A
# 1712  119, grove street, closter
# 1713  12, wills way, piscataway township
# 1714  130, maple avenue, closter
# 1715  7817, bergenline avenue, hudson heights
# 1716  55, leonardville road, leonardville
# 1717  1868, hooper avenue, silverton
# 1718 princess road princess road, lawrence township, mercer county
# 1719  12, wills way, piscataway township
# 1720 us highway 130 us highway 130, east windsor township, mercer county
# 1721  519, new brunswick avenue, rahway
# 1722 N/A N/A
# 1723  12, wills way, piscataway township
# 1724 ankle & foot associates north: mc evoy john j dpm ankle & foot associates north: mc evoy john j dpm, 504, paterson-hamburg turnpike
# 1725  550, newark avenue, journal square
# 1726  130, maple avenue, closter
# 1727 N/A N/A
# 1728 N/A N/A
# 1729 N/A N/A
# 1730 N/A N/A
# 1731  2501, kuser road, haines corner
# 1732  109, south main street, laguna oaks
# 1733  31, smull avenue, caldwell
# 1734  1, west ridgewood avenue, downtown ridgewood
# 1735 millburn avenue millburn avenue, union, union county
# 1736  20, prospect avenue, montclair
# 1737  24, bergen street, englewood
# 1738  370, grand avenue, davisville
# 1739  1270, south beverwyck road, parsippany-troy hills
# 1740 dr. robert s. delagente, do dr. robert s. delagente, do, 468
# 1741  1156, springfield avenue, irvington
# 1742  2, sears drive, paramus
# 1743  5, franklin avenue, witherspoon-jackson
# 1744  240, williamson street, elizabeth
# 1745 N/A N/A
# 1746  363, grand avenue, davisville
# 1747  500, morris avenue, spring lake
# 1748  285, north beverwyck road, lake hiawatha
# 1749 N/A N/A
# 1750  905, allwood road, clifton
# 1751  1625, anderson avenue, koreatown
# 1752  240, williamson street, elizabeth
# 1753  83, hanover road, cooks bridge
# 1754  24, bergen street, englewood
# 1755  200, south orange avenue, university heights
# 1756 kinderkamack road kinderkamack road, westwood, bergen county
# 1757 N/A N/A
# 1758 kinderkamack road kinderkamack road, westwood, bergen county
# 1759  1033, clifton avenue, athenia
# 1760 michael moore, md michael moore, md, 171
# 1761  9, mount bethel road, warrenville
# 1762  4, hunter street, lodi
# 1763  22, madison avenue, montclair
# 1764  55, gilbert street north, tinton falls
# 1765  542, anderson avenue, alpine
# 1766  1200, green street, iselin
# 1767  8, south morris street, dover
# 1768  970, bard avenue, sunset hill
# 1769  400, old hook road, westwood
# 1770  9, mount bethel road, warrenville
# 1771  350, bloomfield avenue, newark
# 1772  52, skyline drive, englewood cliffs
# 1773 east brunswick east brunswick, brick plant road, east brunswick township
# 1775 N/A N/A
# 1776  1600, east saint georges avenue, linden
# 1777  1, journal concourse square west, journal square
# 1778  20, prospect avenue, montclair
# 1779  877, broadway, west norwood
# 1780 clifton dental associates clifton dental associates, 1005, clifton avenue
# 1781 N/A N/A
# 1782 N/A N/A
# 1783 oradell oradell, oradell avenue, oradell
# 1784 comfort inn edgewater comfort inn edgewater, 725, river road
# 1785  1308, morris avenue, union
# 1786  925, clifton avenue, athenia
# 1787  20, east 46th street, manhattan community board 5
# 1788 oradell oradell, oradell avenue, oradell
# 1789  1203, langhorne-yardley road, highland gate
# 1790  125, washington avenue, villas
# 1791 hold middle acupuncture hold middle acupuncture, 66, east 80th street
# 1792  400, old hook road, westwood
# 1794 N/A N/A
# 1795  116, washington crossing-pennington road, harts corner
# 1796  20, east 46th street, manhattan community board 5
# 1797  264, boyden avenue, newark heights
# 1798  528, boulevard, brookchester apartment homes
# 1799  20, east 46th street, manhattan community board 5
# 1800  182, south new york road, quail hill professional park
# 1801  240, williamson street, elizabeth
# 1802  215, old tappan road, old tappan
# 1803 spectrum therapeutics of nj spectrum therapeutics of nj, 401, paterson-hamburg turnpike
# 1804  842, clifton avenue, athenia
# 1806 re/max classic group re/max classic group, 3322, us 22
# 1807 N/A N/A
# 1809  50, union avenue, berlin
# 1810  7318, frankford avenue, mayfair
# 1811 nj physical therapy nj physical therapy, 342, paterson-hamburg turnpike
# 1812  217, bethpage road, hicksville
# 1813  370, grand avenue, davisville
# 1814 N/A N/A
# 1815 railroad avenue railroad avenue, coxstown, eagleswood township
# 1816  308, main street, village of farmingdale
# 1817  970, bard avenue, sunset hill
# 1818 the juilliard school the juilliard school, 60, west 66th street
# 1820  83, hanover road, cooks bridge
# 1821 my best practice my best practice, 280, madison avenue
# 1822 starbucks starbucks, 800, denow road
# 1823 spectrum therapeutics of nj spectrum therapeutics of nj, 401, paterson-hamburg turnpike
# 1824  7318, frankford avenue, mayfair
# 1825 subway subway, 111, broadway
# 1826 michael moore, md michael moore, md, 171
# 1827  12, wills way, piscataway township
# 1828  156, william street, whitehall
# 1829  953, fischer boulevard, bellcrest park
# 1830  3520, us highway 9, freehold township
# 1834  40, bey lea road, bey lea
# 1835 N/A N/A
# 1836 N/A N/A
# 1837  40, bey lea road, bey lea
# 1838  731, lacey road, cranberry hill
# 1839  855, valley road, montclair heights
# 1841 N/A N/A
# 1843  701, east main street, finderne
# 1844  34, the promenade, edgewater
# 1845 crowne plaza crowne plaza, 401, south van brunt street
# 1846 N/A N/A
# 1847 N/A N/A
# 1849 N/A N/A
# 1850  185, central avenue, koreatown
# 1854 N/A N/A
# 1856 central jersey urgent care of eatontown central jersey urgent care of eatontown, 142, main street
# 1857 millburn avenue millburn avenue, union, union county
# 1858  35, south washington avenue, bergenfield
# 1859  1265, springfield avenue, irvington
# 1860  21, angela drive, forest edge estates
# 1861  757, teaneck road, copley estates
# 1862  195, cortlandt street, belleville
# 1863 gemstone gallery gemstone gallery, 17, bridge street
# 1864 stelton road stelton road, north stelton, piscataway township
# 1865 N/A N/A
# 1866  999, mcbride avenue, woodland park
# 1868  714, bergen boulevard, ridgefield
# 1869  20, valley street, hillsdale
# 1870  1187, main avenue, clifton
# 1871  16, arcadian way, arcola
# 1872  55, morris avenue, haworth
# 1873 the columns the columns, 47, orient way
# 1874  859, clifton avenue, athenia
# 1875 us highway 46 us highway 46, lodi, bergen county
# 1876 N/A N/A
# 1878  323, washington street, downtown
# 1880  7, broad avenue, koreatown
# 1881 N/A N/A
# 1882  1270, south beverwyck road, parsippany-troy hills
# 1883 N/A N/A
# 1884  1150, teaneck road, colonial village
# 1885 woodbourne road woodbourne road, quincy hollow, middletown township
# 1886  207, lakeview avenue, wanamassa
# 1887  449, mount pleasant avenue, woodland park
# 1889 us highway 46 us highway 46, lodi, bergen county
# 1890 the columns the columns, 47, orient way
# 1891  45, pearl street, metuchen
# 1892 ridgewood internal medicine ridgewood internal medicine, 190, dayton street
# 1893  18, redneck avenue, little ferry
# 1895  757, teaneck road, copley estates
# 1896  145, wyckoff road, eatonbrook
# 1897  1364, bunker hill drive, willowdale
# 1898  44, godwin avenue, fair lawn
# 1899 N/A N/A
# 1900 N/A N/A
# 1901  9, presidential boulevard, sutton terrace
# 1902 N/A N/A
# 1903  46, essex street, hackensack
# 1904  1364, bunker hill drive, willowdale
# 1905 N/A N/A
# 1906  23, mountain boulevard, warrenville
# 1907  2100, corlies avenue, west grove
# 1908 N/A N/A
# 1909  579, otterhole road, west milford
# 1910 N/A N/A
# 1911 N/A N/A
# 1913 N/A N/A
# 1914 advanced surgical & bariatrics advanced surgical & bariatrics, 81, veronica avenue
# 1915  43, gilbert street north, tinton falls
# 1916  228, franklin avenue, seaside heights
# 1917  200, engle street, englewood
# 1918 overlook emergency services – union campus overlook emergency services – union campus, 1000, galloping hill road
# 1919 route 22 route 22, north plainfield, somerset county
# 1920  440, chestnut street, englewood cliffs
# 1921  3200, sunset avenue, wanamassa
# 1922  60, evergreen place, demarest
# 1923 N/A N/A
# 1925  166, morris avenue, haworth
# 1926  310, central avenue, englewood
# 1927 N/A N/A
# 1928  7500, bergenline avenue, north bergen
# 1929  705, white horse road, glendale
# 1930 millburn avenue millburn avenue, union, union county
# 1931  526, lippincott drive, marlton
# 1932  34, the promenade, edgewater
# 1934  230, sherman avenue, deal park
# 1935 windsor medical center, pa windsor medical center, pa, 339
# 1937  6, cornwall court, east brunswick township
# 1938 N/A N/A
# 1939 N/A N/A
# 1940  230, sherman avenue, deal park
# 1941 s dental & specialties s dental & specialties, 50, essex street
# 1942 N/A N/A
# 1945 N/A N/A
# 1947 N/A N/A
# 1948 route 37 west route 37 west, manchester township, ocean county
# 1950 N/A N/A
# 1951  207, lakeview avenue, wanamassa
# 1953  70, ramtown-greenville road, ramtown manor
# 1955 overlook emergency services – union campus overlook emergency services – union campus, 1000, galloping hill road
# 1957 N/A N/A
# 1958  780, cedar lane, teaneck township
# 1961 N/A N/A
# 1963  759, hamburg turnpike, wayne
# 1964 starbucks starbucks, 800, denow road
# 1965 N/A N/A
# 1966 N/A N/A
# 1969 N/A N/A
# 1982 N/A N/A
# 1988  66, macculloch avenue, dublin
# 1991  1767, morris avenue, union
# 1995  11, dundar road, springfield
# 2000 N/A N/A
# 2003  206, washington street, northvale
# 2004  94, valley road, haworth
# 2007  333, old hook road, westwood
# 2011 N/A N/A
# 2039  61, pearl street, dumont
# 2046  220, saint paul street, westfield
# 2079  94, valley road, haworth
# 2085  992, clifton avenue, athenia
# 2091  1560, springfield avenue, newark heights
# 2104  241, maple avenue, oradell
# 2107  2, paragon way, freehold township
# 2110  1400, hooper avenue, friar's cove
# 2111 N/A N/A
# 2118  601, south henderson road, school side manor
# 2119  317, godwin avenue, wortendyke
# 2132 N/A N/A
# 2133 burger king burger king, 185, 12th street
# 2134 N/A N/A
# 2135 burger king burger king, 185, 12th street
# 2136 N/A N/A
# 2137 N/A N/A
# 2138  305, west grand avenue, rahway
# 2139 saint peter's university hospital saint peter's university hospital, 254, easton avenue
# 2140 westwood post office westwood post office, fairview avenue, westwood
# 2141  4045, hempstead turnpike, bethpage
# 2142 N/A N/A
# 2143  12, east 86th street, manhattan community board 8
# 2144  4813, 9th avenue, borough park
# 2145 N/A N/A
# 2146  7, 7th avenue, brooklyn
# 2147  122, east 76th street, lenox hill
# 2148 emu health emu health, 83-40, woodhaven boulevard
# 2149  200, engle street, englewood
# 2150 us highway 46 us highway 46, lodi, bergen county
# 2151  16, arcadian way, arcola
# 2152 the columns the columns, 47, orient way
# 2153  3200, sunset avenue, wanamassa
# 2154  1364, bunker hill drive, willowdale
# 2155  46, essex street, hackensack
# 2156  367, lakehurst road, camelot
# 2158 burger king burger king, 185, 12th street
# 2159  780, cedar lane, teaneck township
# 2160 N/A N/A
# 2161  855, valley road, montclair heights
# 2162  759, hamburg turnpike, wayne
# 2163 N/A N/A
# 2165 N/A N/A
# 2166 the dentists llc the dentists llc, 870, palisade avenue
# 2167 N/A N/A
# 2168  367, lakehurst road, camelot
# 2169  544, washington avenue, woodbine
# 2170  70, ramtown-greenville road, ramtown manor
# 2171 N/A N/A
# 2172 burger king burger king, 185, 12th street
# 2173  1144, east ridgewood avenue, southeast ridgewood
# 2174 N/A N/A
# 2175  759, hamburg turnpike, wayne
# 2176  1255, whitehorse mercerville road, hamilton township
# 2177 N/A N/A
# 2178 N/A N/A
# 2179 holy name medical center holy name medical center, 718, teaneck road
# 2180  3840, park avenue, weehawken
# 2181 highland financial advisors, llc highland financial advisors, llc, 1680
# 2182  1, west ridgewood avenue, downtown ridgewood
# 2183  222, cedar lane, copley estates
# 2184  1, west ridgewood avenue, downtown ridgewood
# 2185  5, plainsboro road, plainsboro township
# 2186  1, journal concourse square west, journal square
# 2187  464, hudson terrace, englewood cliffs
# 2188  309, engle street, tenafly
# 2189 N/A N/A
# 2190 iorio plastic surgery and medspa iorio plastic surgery and medspa, 101, crawfords corner road
# 2191 N/A N/A
# 2192 alexandria deli & grocery alexandria deli & grocery, 79, saratoga avenue
# 2193 2 journal square plaza 2 journal square plaza, 2, john f. kennedy boulevard
# 2194 iorio plastic surgery and medspa iorio plastic surgery and medspa, 101, crawfords corner road
# 2195 highland financial advisors, llc highland financial advisors, llc, 1680
# 2196 N/A N/A
# 2197  575, underhill boulevard, syosset
# 2198  80, colonial road, village of floral park
# 2199 N/A N/A
# 2200  200, south orange avenue, university heights
# 2201  1, journal concourse square west, journal square
# 2202  1, journal concourse square west, journal square
# 2203 N/A N/A
# 2204 N/A N/A
# 2205 holy name medical center holy name medical center, 718, teaneck road
# 2206  95, greenleaf hill, saddle rock homes at saddle rock
# 2207  630, broad street, ridgewood junction
# 2208 nj physical therapy nj physical therapy, 342, paterson-hamburg turnpike
# 2209 clifton clifton, elm street, athenia
# 2210  9226, john f. kennedy boulevard, hudson heights
# 2211  2333, morris avenue, unionburg
# 2212 holy name medical center holy name medical center, 718, teaneck road
# 2213  4813, 9th avenue, borough park
# 2214  210, west saint georges avenue, linden
# 2215  186, east 76th street, lenox hill
# 2216 N/A N/A
# 2217 N/A N/A
# 2218  5, plainsboro road, plainsboro township
# 2219 N/A N/A
# 2220  186, east 76th street, lenox hill
# 2221  443, northfield avenue, saint cloud
# 2222  116, south euclid avenue, westfield
# 2223  155, east 76th street, lenox hill
# 2224 N/A N/A
# 2225 starbucks starbucks, 50, court street
# 2226  769, 54th street, borough park
# 2227 N/A N/A
# 2228  90, millburn avenue, millburn
# 2229  156, williams street, village of lawrence
# 2230 bayonne medical center bayonne medical center, 29, east 29th street
# 2231  54, south dean street, englewood
# 2233 N/A N/A
# 2234  54, south dean street, englewood
# 2235 N/A N/A
# 2236  300, perrine road, cedarview estates
# 2237  200, east 78th street, manhattan community board 8
# 2238 starbucks starbucks, 50, court street
# 2239 west 8th street west 8th street, ship bottom, ocean county
# 2240  79, hudson street, downtown
# 2241 kennedy boulevard kennedy boulevard, coventry square, lakewood township
# 2242 N/A N/A
# 2243  372, central park west, manhattan community board 7
# 2244  2339, hempstead turnpike, east meadow
# 2245  2510, westchester avenue, bronx county
# 2246  3250, westchester avenue, pelham bay
# 2247  630, broad street, ridgewood junction
# 2248 N/A N/A
# CPU times: user 10.6 s, sys: 631 ms, total: 11.2 s
# Wall time: 27min 50s

# %%
df.to_csv('df_combined_facility.csv', index=False)
